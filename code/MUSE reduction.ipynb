# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from astropy.io import fits

# %%
path = '/Users/isabelkain/Desktop/MUSE'

hdul = fits.open(f'{path}/M.MUSE.2018-04-23T13_07_20.140.fits')
np.shape(hdul)
# Out:
# WARNING: File may have been truncated: actual file length (2836303872) is smaller than the expected size (2898072000) [astropy.io.fits.file]
# (44,)

# %%
# Contents of the hdu list:

# 0. (no data, just overall header)
# 1. CHAN01.DATA     
# 2. CHAN01.DQ       # bad pixel mask
# 3. CHAN01.STAT
# 4. CHAN02.DATA
# 5. CHAN02.DQ
# 6. CHAN02.STAT
# (…)
# 43. CHAN15.DATA # missing channel 15 stat and DQ


# For the data files:
#     HDUCLAS1= 'IMAGE   '
#     HDUCLAS2= 'DATA    '
    
# For the DQ masks:
#     HDUCLAS1= 'IMAGE   '
#     HDUCLAS2= 'QUALITY '
#     HDUCLAS3= 'FLAG32BIT'
#     SCIDATA = 'CHAN01.DATA' # pointer to the data extension
#     ERRDATA = 'CHAN01.STAT' # pointer to the variance extension
    
# For the stat frames:
#     HDUCLAS1= 'IMAGE   '
#     HDUCLAS2= 'ERROR   ' 
#     HDUCLAS3= 'MSE     ' # the extension contains variances (sigma**2)
#     SCIDATA = 'CHAN01.DATA'
#     QUALDATA= 'CHAN01.DQ'

# %%
hdul[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                    8 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2018-04-22T17:01:06' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# INSTRUME= 'MUSE    '           / Instrument used.
# TELESCOP= 'ESO-VLT-U4'         / ESO <TEL>
# OBJECT  = 'FLAT,LAMP'          / Original target.
# ORIGIN  = 'ESO-PARANAL'        / European Southern Observatory
# PI-COI  = 'MUSE Operation Team' / PI-COI name.
# EXPTIME =                 102. / Integration time
# MJD-OBS =       58230.58326183 / Obs start
# DATE-OBS= '2018-04-22T13:59:53.000' / Observing date
# PIPEFILE= 'r.MUSE.2018-04-22T13:59:53.822_tpl_0000.fits' / no comment
# ...

# %%
hdul[0].header['*PRO CATG*']
# Out:
# HIERARCH ESO PRO CATG = 'MASTER_FLAT' / Category of pipeline product frame

# %%
plt.figure(figsize=(8,8))
plt.imshow(hdul[2].data)

print(np.sum(hdul[2].data)/np.shape(hdul[2].data)[0]**2)
# Out:
# 6.225998879619676

# %%
hdul[2].header
# Out:
# XTENSION= 'IMAGE   '           / IMAGE extension
# BITPIX  =                   32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 4096 / length of data axis 1
# NAXIS2  =                 4112 / length of data axis 2
# PCOUNT  =                    0 / required keyword; must = 0
# GCOUNT  =                    1 / required keyword; must = 1
# EXTNAME = 'CHAN01.DQ'          / FITS Extension name
# HDUCLASS= 'ESO     '           / class name (ESO format)
# HDUCLAS1= 'IMAGE   '           / Image data format
# HDUCLAS2= 'QUALITY '           / this extension contains bad pixel mask
# HDUCLAS3= 'FLAG32BIT'          / extension contains 32bit Euro3D bad pixel infor
# HDUDOC  = 'DICD    '           / document with class description
# HDUVERS = 'DICD version 6'     / version number (according to spec v2.5.1)
# SCIDATA = 'CHAN01.DATA'        / pointer to the data extension
# ...
